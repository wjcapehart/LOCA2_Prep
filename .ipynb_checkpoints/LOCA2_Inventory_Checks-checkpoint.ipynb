# %% [markdown]
# # LOCA2 Inventory Checks

# %% [markdown]
# ## Libraries

# %%
######################################################
#
# Libraries
#


import os    as os

import numpy as np

import xarray as xr

import pandas as pd

import matplotlib.pyplot as plt

#
######################################################

# %% [markdown]
# ## File Control

# %%
######################################################
#
# File Control
#

working_directory  = "./"

thredds_root_dir   = "/projects/ECEP/LOCA_MACA_Ensembles/LOCA2/LOCA2_CONUS/Original_CONUS/"


loca2_mod_member_file = "http://kyrill.ias.sdsmt.edu:8080/thredds/catalog/LOCA2/Original_CONUS/catalog.html"




Scenarios = ["historical",
                 "ssp245",
                 "ssp370",
                 "ssp585"]

Vars = ["tasmax",
        "tasmin",
            "pr"]

#
######################################################

# %% [markdown]
# ## Pull All Possible Models and Members

# %%
######################################################
#
# Pull Full Inventory List
#

full_models_and_members_list = pd.read_csv(filepath_or_buffer = working_directory + loca2_mod_member_file)

full_models_and_members_list

n_records = len(full_models_and_members_list)

display(full_models_and_members_list)

display(n_records)

#
######################################################
# Out:
#              Model    Member  Var  Season  Stat   NetError  Rank historical  \
# 0        GFDL-ESM4  r1i1p1f1  All  Annual  Both   6.152235     1        XNP
# 1      BCC-CSM2-MR  r1i1p1f1  All  Annual  Both   6.357673     1        XNP
# 2         GFDL-CM4  r1i1p1f1  All  Annual  Both   6.498461     1        XNP
# 3       CNRM-CM6-1  r1i1p1f2  All  Annual  Both   6.513064     1        XNP
# 4          TaiESM1  r1i1p1f1  All  Annual  Both   6.658829     1        XNP
# ..             ...       ...  ...     ...   ...        ...   ...        ...
# 103  MPI-ESM1-2-LR  r6i1p1f1  All  Annual  Both  13.741907     7        NaN
# 104  MPI-ESM1-2-LR  r1i1p1f1  All  Annual  Both  13.742271     8        XNP
# 105  MPI-ESM1-2-LR  r4i1p1f1  All  Annual  Both  14.062717     9        NaN
# 106     KACE-1-0-G  r3i1p1f1  All  Annual  Both  14.453719     3        NaN
# 107  MPI-ESM1-2-HR  r7i1p1f1  All  Annual  Both  14.725488    10        NaN
#
#     ssp245 ssp370 ssp585
# 0      XNP    XNP    XNP
# 1      XNP    XNP    XNP
# 2      XNP    ---    XNP
# 3      XNP    XNP    XNP
# 4      XNP    XNP    ---
# ..     ...    ...    ...
# 103    NaN    ---    NaN
# 104    XNP    XNP    XNP
# 105    NaN    NaN    NaN
# 106    NaN    NaN    NaN
# 107    ---    NaN    ---
#
# [108 rows x 11 columns]
# 108

# %% [markdown]
# ## Scan Disk for Available Files

# %%
######################################################
#
# Scan Disk for Available Files
#

available_rows =  [False for i in range(len(full_models_and_members_list))]


for i in range(len(full_models_and_members_list)):
    
    for k in range(len(Scenarios)):
    
        file_name  = "LOCA2-CONUS___" + full_models_and_members_list.at[i,"Model"]+"."+ full_models_and_members_list.at[i,"Member"]+"___"+Scenarios[k]+".nc"

        #print(file_name)

        file_name  = thredds_root_dir + Scenarios[k] + "/" + file_name

        if os.path.isfile(file_name):

            my_string_all = "---"
            my_string_max = "-"
            my_string_min = "-"
            my_string_pcp = "-"
            xf         = xr.open_dataset(filename_or_obj = file_name)

            if "tasmax" in list(xf.keys()):
                my_string_max = "X"
                available_rows[i] = True
            if "tasmin" in list(xf.keys()):
                my_string_min = "N"        
                available_rows[i] = True
            if "pr"     in list(xf.keys()):
                my_string_pcp = "P"    
                available_rows[i] = True
            full_models_and_members_list.at[i,  Scenarios[k]] = my_string_max+my_string_min+my_string_pcp

display(full_models_and_members_list)


        
#
######################################################
# Out:
#              Model    Member  Var  Season  Stat   NetError  Rank historical  \
# 0        GFDL-ESM4  r1i1p1f1  All  Annual  Both   6.152235     1        XNP
# 1      BCC-CSM2-MR  r1i1p1f1  All  Annual  Both   6.357673     1        XNP
# 2         GFDL-CM4  r1i1p1f1  All  Annual  Both   6.498461     1        XNP
# 3       CNRM-CM6-1  r1i1p1f2  All  Annual  Both   6.513064     1        XNP
# 4          TaiESM1  r1i1p1f1  All  Annual  Both   6.658829     1        XNP
# ..             ...       ...  ...     ...   ...        ...   ...        ...
# 103  MPI-ESM1-2-LR  r6i1p1f1  All  Annual  Both  13.741907     7        NaN
# 104  MPI-ESM1-2-LR  r1i1p1f1  All  Annual  Both  13.742271     8        XNP
# 105  MPI-ESM1-2-LR  r4i1p1f1  All  Annual  Both  14.062717     9        NaN
# 106     KACE-1-0-G  r3i1p1f1  All  Annual  Both  14.453719     3        NaN
# 107  MPI-ESM1-2-HR  r7i1p1f1  All  Annual  Both  14.725488    10        NaN
#
#     ssp245 ssp370 ssp585
# 0      XNP    XNP    XNP
# 1      XNP    XNP    XNP
# 2      XNP    ---    XNP
# 3      XNP    XNP    XNP
# 4      XNP    XNP    ---
# ..     ...    ...    ...
# 103    NaN    ---    NaN
# 104    XNP    XNP    XNP
# 105    NaN    NaN    NaN
# 106    NaN    NaN    NaN
# 107    ---    NaN    ---
#
# [108 rows x 11 columns]

# %%
full_models_and_members_list
# Out:
#              Model    Member  Var  Season  Stat   NetError  Rank historical  \
# 0        GFDL-ESM4  r1i1p1f1  All  Annual  Both   6.152235     1        XNP
# 1      BCC-CSM2-MR  r1i1p1f1  All  Annual  Both   6.357673     1        XNP
# 2         GFDL-CM4  r1i1p1f1  All  Annual  Both   6.498461     1        XNP
# 3       CNRM-CM6-1  r1i1p1f2  All  Annual  Both   6.513064     1        XNP
# 4          TaiESM1  r1i1p1f1  All  Annual  Both   6.658829     1        XNP
# ..             ...       ...  ...     ...   ...        ...   ...        ...
# 103  MPI-ESM1-2-LR  r6i1p1f1  All  Annual  Both  13.741907     7        NaN
# 104  MPI-ESM1-2-LR  r1i1p1f1  All  Annual  Both  13.742271     8        XNP
# 105  MPI-ESM1-2-LR  r4i1p1f1  All  Annual  Both  14.062717     9        NaN
# 106     KACE-1-0-G  r3i1p1f1  All  Annual  Both  14.453719     3        NaN
# 107  MPI-ESM1-2-HR  r7i1p1f1  All  Annual  Both  14.725488    10        NaN
#
#     ssp245 ssp370 ssp585
# 0      XNP    XNP    XNP
# 1      XNP    XNP    XNP
# 2      XNP    ---    XNP
# 3      XNP    XNP    XNP
# 4      XNP    XNP    ---
# ..     ...    ...    ...
# 103    NaN    ---    NaN
# 104    XNP    XNP    XNP
# 105    NaN    NaN    NaN
# 106    NaN    NaN    NaN
# 107    ---    NaN    ---
#
# [108 rows x 11 columns]

# %% [markdown]
# ## Save Data

# %%
######################################################
#
# Save Full Inventory
#

full_models_and_members_list.to_csv(path_or_buf = working_directory + loca2_mod_member_file,
                                   index        =  False,
                                   na_rep       =     '')

#
######################################################

# %% [markdown]
# # Cut only available files

# %%
######################################################
#
# Trim Only Available Ones
#

avail_models_and_members_list = full_models_and_members_list.copy()

avail_models_and_members_list = avail_models_and_members_list[available_rows]
                                                              
                                                              
display(avail_models_and_members_list)

avail_models_and_members_list.to_csv(path_or_buf = working_directory + "LOCA2_Model_Member_Available_List.csv",
                                   index        =  False,
                                   na_rep       =     '')

os.system("scp ./LOCA2_Model_Member_Available_List.csv wjc@kyrill:"+thredds_root_dir)
os.system("scp ./LOCA2_Model_Member_Complete_List.csv wjc@kyrill:"+thredds_root_dir)

#
######################################################
# Out:
#                Model     Member  Var  Season  Stat   NetError  Rank  \
# 0          GFDL-ESM4   r1i1p1f1  All  Annual  Both   6.152235     1
# 1        BCC-CSM2-MR   r1i1p1f1  All  Annual  Both   6.357673     1
# 2           GFDL-CM4   r1i1p1f1  All  Annual  Both   6.498461     1
# 3         CNRM-CM6-1   r1i1p1f2  All  Annual  Both   6.513064     1
# 4            TaiESM1   r1i1p1f1  All  Annual  Both   6.658829     1
# 5        CNRM-ESM2-1   r1i1p1f2  All  Annual  Both   6.681317     1
# 6      CNRM-CM6-1-HR   r1i1p1f2  All  Annual  Both   6.990708     1
# 7          INM-CM4-8   r1i1p1f1  All  Annual  Both   7.238094     1
# 8             MIROC6   r1i1p1f1  All  Annual  Both   8.165782     1
# 9         MRI-ESM2-0   r5i1p1f1  All  Annual  Both   9.399468     1
# 10         INM-CM5-0   r4i1p1f1  All  Annual  Both   9.595832     1
# 11   HadGEM3-GC31-MM   r2i1p1f3  All  Annual  Both   9.730879     1
# 12         INM-CM5-0   r3i1p1f1  All  Annual  Both   9.848350     2
# 13        NorESM2-LM   r2i1p1f1  All  Annual  Both   9.902020     1
# 14         INM-CM5-0   r1i1p1f1  All  Annual  Both   9.920685     3
# 15         FGOALS-g3   r3i1p1f1  All  Annual  Both   9.930760     1
# 16         FGOALS-g3   r1i1p1f1  All  Annual  Both   9.942837     2
# 17     ACCESS-ESM1-5   r1i1p1f1  All  Annual  Both  10.086129     1
# 18   HadGEM3-GC31-LL   r3i1p1f3  All  Annual  Both  10.124722     1
# 19         EC-Earth3   r2i1p1f1  All  Annual  Both  10.146428     1
# 20        MRI-ESM2-0   r1i1p1f1  All  Annual  Both  10.193135     2
# 21        NorESM2-MM   r2i1p1f1  All  Annual  Both  10.246951     1
# 22        NorESM2-LM   r3i1p1f1  All  Annual  Both  10.250854     2
# 23        NorESM2-LM   r1i1p1f1  All  Annual  Both  10.302912     3
# 24   HadGEM3-GC31-MM   r1i1p1f3  All  Annual  Both  10.323759     2
# 25            MIROC6   r2i1p1f1  All  Annual  Both  10.395672     2
# 27           CanESM5   r1i1p1f1  All  Annual  Both  10.595282     1
# 28        ACCESS-CM2   r1i1p1f1  All  Annual  Both  10.657392     1
# 29     ACCESS-ESM1-5   r5i1p1f1  All  Annual  Both  10.676142     2
# 31        ACCESS-CM2   r3i1p1f1  All  Annual  Both  10.747093     2
# 33        CESM2-LENS   r4i1p1f1  All  Annual  Both  10.875201     1
# 34         EC-Earth3   r4i1p1f1  All  Annual  Both  10.884393     2
# 35      IPSL-CM6A-LR   r3i1p1f1  All  Annual  Both  10.900917     1
# 36        CESM2-LENS   r6i1p1f1  All  Annual  Both  10.906420     2
# 38     EC-Earth3-Veg   r4i1p1f1  All  Annual  Both  10.940750     1
# 42        NorESM2-MM   r1i1p1f1  All  Annual  Both  11.102702     2
# 46     EC-Earth3-Veg   r3i1p1f1  All  Annual  Both  11.244554     2
# 47        KACE-1-0-G   r2i1p1f1  All  Annual  Both  11.248111     1
# 49        CESM2-LENS   r1i1p1f1  All  Annual  Both  11.249889     6
# 52   HadGEM3-GC31-LL   r2i1p1f3  All  Annual  Both  11.357376     2
# 53   HadGEM3-GC31-LL   r1i1p1f3  All  Annual  Both  11.360018     3
# 54        KACE-1-0-G   r1i1p1f1  All  Annual  Both  11.367058     2
# 55      IPSL-CM6A-LR   r2i1p1f1  All  Annual  Both  11.433722     2
# 58     MPI-ESM1-2-HR  r10i1p1f1  All  Annual  Both  11.568492     1
# 60         EC-Earth3   r1i1p1f1  All  Annual  Both  11.582314     4
# 67      IPSL-CM6A-LR   r1i1p1f1  All  Annual  Both  11.812705     6
# 68     MPI-ESM1-2-HR   r2i1p1f1  All  Annual  Both  11.849895     2
# 69     MPI-ESM1-2-LR  r10i1p1f1  All  Annual  Both  11.950732     1
# 70     AWI-CM-1-1-MR   r1i1p1f1  All  Annual  Both  11.980818     1
# 73           CanESM5   r4i1p1f1  All  Annual  Both  12.075595     2
# 75     AWI-CM-1-1-MR   r2i1p1f1  All  Annual  Both  12.166347     2
# 77     MPI-ESM1-2-LR   r3i1p1f1  All  Annual  Both  12.257651     2
# 78     EC-Earth3-Veg   r1i1p1f1  All  Annual  Both  12.301219     4
# 81     MPI-ESM1-2-HR   r1i1p1f1  All  Annual  Both  12.387494     4
# 104    MPI-ESM1-2-LR   r1i1p1f1  All  Annual  Both  13.742271     8
#
#     historical ssp245 ssp370 ssp585
# 0          XNP    XNP    XNP    XNP
# 1          XNP    XNP    XNP    XNP
# 2          XNP    XNP    ---    XNP
# 3          XNP    XNP    XNP    XNP
# 4          XNP    XNP    XNP    ---
# 5          XNP    XNP    XNP    XNP
# 6          XNP    ---    ---    XNP
# 7          XNP    XNP    XNP    XNP
# 8          XNP    XNP    XNP    XNP
# 9          XNP    ---    XNP    ---
# 10         XNP    ---    XNP    ---
# 11         XNP    ---    ---    XNP
# 12         XNP    ---    XNP    ---
# 13         XNP    XNP    ---    ---
# 14         XNP    XNP    XNP    XNP
# 15         XNP    XNP    XNP    XNP
# 16         XNP    XNP    XNP    XNP
# 17         XNP    XNP    XNP    XNP
# 18         XNP    ---    ---    XNP
# 19         XNP    XNP    ---    ---
# 20         XNP    XNP    XNP    XNP
# 21         XNP    XNP    ---    ---
# 22         XNP    XNP    ---    ---
# 23         XNP    XNP    XNP    XNP
# 24         XNP    ---    ---    XNP
# 25         XNP    XNP    XNP    XNP
# 27         XNP    XNP    XNP    XNP
# 28         XNP    XNP    XNP    XNP
# 29         XNP    XNP    XNP    XNP
# 31         XNP    XNP    XNP    XNP
# 33         XNP    ---    XNP    ---
# 34         XNP    XNP    XNP    XNP
# 35         XNP    XNP    XNP    XNP
# 36         XNP    ---    XNP    ---
# 38         XNP    XNP    XNP    XNP
# 42         XNP    XNP    XNP    XNP
# 46         XNP    XNP    XNP    XNP
# 47         XNP    XNP    XNP    XNP
# 49         XNP    ---    XNP    ---
# 52         XNP    ---    ---    XNP
# 53         XNP    ---    ---    XNP
# 54         XNP    XNP    XNP    XNP
# 55         XNP    XNP    XNP    XNP
# 58         XNP    ---    XNP    ---
# 60         XNP    XNP    XNP    XNP
# 67         XNP    XNP    XNP    XNP
# 68         XNP    XNP    XNP    XNP
# 69         XNP    XNP    XNP    --P
# 70         XNP    XNP    XNP    XNP
# 73         XNP    XNP    XNP    XNP
# 75         XNP    ---    XNP    ---
# 77         XNP    XNP    XNP    XNP
# 78         XNP    XNP    XNP    XNP
# 81         XNP    XNP    XNP    XNP
# 104        XNP    XNP    XNP    XNP
# 0
